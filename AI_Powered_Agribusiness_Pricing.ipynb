# %% [markdown]
# <a href="https://colab.research.google.com/github/haliberry29/SadiyaTijjaniBaba_MachineLearning/blob/main/AI_Powered_Agribusiness_Pricing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# | Column Name                     | Description                                                                      |
# | ------------------------------- | -------------------------------------------------------------------------------- |
# | `farm_id`                       | Unique identifier for each farm operation or agricultural site                   |
# | `region`                        | Geographic region where the farm is located                                      |
# | `crop_type`                     | Type of crop being cultivated (e.g., corn, soybean, wheat)                       |
# | `soil_moisture_%`               | Soil water content percentage indicating moisture availability                   |
# | `soil_pH`                       | Soil acidity/alkalinity measurement affecting crop growth                        |
# | `temperature_C`                 | Average environmental temperature in Celsius                                     |
# | `rainfall_mm`                   | Total rainfall amount in millimeters                                             |
# | `humidity_%`                    | Atmospheric humidity percentage                                                  |
# | `sunlight_hours`                | Number of sunlight exposure hours received                                       |
# | `irrigation_type`               | Irrigation method used (drip, sprinkler, flood, etc.)                            |
# | `fertilizer_type`               | Type of fertilizer applied to crops                                              |
# | `pesticide_usage_ml`            | Amount of pesticide applied in milliliters                                       |
# | `sowing_date`                   | Date when crops were planted                                                     |
# | `harvest_date`                  | Date when crops were harvested                                                   |
# | `total_days`                    | Total crop growth duration between sowing and harvest                            |
# | `yield_kg_per_hectare`          | Crop production yield per hectare                                                |
# | `sensor_id`                     | Identifier for IoT or agricultural monitoring sensor                             |
# | `timestamp`                     | Date-time record of observation or sensor reading                                |
# | `latitude`                      | Geographic latitude coordinate of the farm                                       |
# | `longitude`                     | Geographic longitude coordinate of the farm                                      |
# | `NDVI_index`                    | Normalized Difference Vegetation Index measuring crop health from remote sensing |
# | `crop_disease_status`           | Indicates whether crops are healthy or affected by disease                       |
# | `product_price`                 | Selling price of agricultural product or input                                   |
# | `quantity_sold`                 | Number of units sold                                                             |
# | `revenue`                       | Total revenue generated from sales                                               |
# | `discount_pct`                  | Discount percentage applied during sale                                          |
# | `corn_futures_price`            | Market futures price for corn commodity                                          |
# | `soybean_futures_price`         | Market futures price for soybean commodity                                       |
# | `fertilizer_market_index`       | Market index representing fertilizer price trends                                |
# | `diesel_price`                  | Diesel fuel price impacting machinery and logistics costs                        |
# | `inflation_rate`                | General inflation percentage affecting operational costs                         |
# | `competitor_price`              | Estimated competitor pricing for similar products                                |
# | `customer_segment`              | Classification of customer type (small farm, enterprise, cooperative, etc.)      |
# | `farm_size_hectares`            | Total farm operational area in hectares                                          |
# | `purchase_frequency`            | Number of purchases made within a defined period                                 |
# | `customer_lifetime_value`       | Estimated long-term customer revenue value                                       |
# | `demand_index`                  | Relative measure of market demand intensity                                      |
# | `regional_market_share_pct`     | Estimated percentage of regional market controlled                               |
# | `week`                          | Week number extracted from timestamp                                             |
# | `quarter`                       | Fiscal quarter extracted from timestamp                                          |
# | `season`                        | Agricultural season classification (Spring, Summer, Fall, Winter)                |
# | `holiday_flag`                  | Binary indicator identifying holiday periods                                     |
# | `drought_index`                 | Numerical indicator of drought severity                                          |
# | `heat_stress_index`             | Crop heat stress severity indicator                                              |
# | `flood_risk_score`              | Estimated flood vulnerability score                                              |
# | `soil_health_score`             | Composite soil quality and fertility score                                       |
# | `crop_disease_risk`             | Estimated probability/risk category of crop disease occurrence                   |
# | `water_availability_index`      | Relative water resource availability indicator                                   |
# | `inventory_level`               | Available inventory stock quantity                                               |
# | `supplier_risk_score`           | Supplier reliability and supply chain risk indicator                             |
# | `logistics_cost`                | Transportation and delivery cost estimate                                        |
# | `lead_time_days`                | Estimated delivery or replenishment lead time                                    |
# | `unit_cost`                     | Estimated operational or production cost per unit                                |
# | `profit_margin`                 | Profit percentage after subtracting costs from price                             |
# | `pricing_recommendation`        | AI-generated pricing action recommendation                                       |
# | `pricing_recommendation_reason` | Explanation supporting the pricing recommendation                                |
# | `hormuz_scenario`               | Simulated geopolitical disruption scenario related to Strait of Hormuz           |
# | `oil_price_shock_multiplier`    | Multiplier representing oil price shock severity                                 |
# | `adjusted_diesel_price`         | Diesel price adjusted for geopolitical disruptions                               |
# | `adjusted_fertilizer_index`     | Fertilizer price index adjusted for energy market shocks                         |
# | `adjusted_logistics_cost`       | Logistics cost adjusted for fuel and supply chain disruption                     |
# | `supply_chain_disruption_score` | Composite indicator of supply chain instability                                  |
# | `farm_input_inflation_pct`      | Estimated inflation percentage in agricultural input costs                       |
# | `adjusted_unit_cost`            | Production cost adjusted for geopolitical and inflationary pressure              |
# | `revenue_risk_score`            | Estimated financial risk exposure to revenue                                     |
# | `margin_compression_pct`        | Percentage reduction in profit margin due to rising costs                        |
# | `adjusted_profit_margin`        | Profit margin after geopolitical and inflation adjustments                       |
# | `revenue_at_risk`               | Estimated revenue potentially lost under disruption scenarios                    |
# | `geopolitical_pricing_strategy` | Recommended pricing strategy under geopolitical conditions                       |
# | `geopolitical_business_summary` | AI-generated business interpretation of geopolitical risk conditions             |

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/sample_data/Smart_Farming_Crop_Yield_2024_2.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'farm_id', 'region', 'crop_type', 'soil_moisture_%',
#        'soil_pH', 'temperature_C', 'rainfall_mm', 'humidity_%',
#        'sunlight_hours', 'irrigation_type', 'fertilizer_type',
#        'pesticide_usage_ml', 'sowing_date', 'harvest_date', 'total_days',
#        'yield_kg_per_hectare', 'sensor_id', 'timestamp', 'latitude',
#        'longitude', 'NDVI_index', 'crop_disease_status', 'product_price',
#        'quantity_sold', 'revenue', 'discount_pct'],
#       dtype='object')

# %%
df.isnull().sum() #checking for empty/missing data
# Out:
# Unnamed: 0                0
# farm_id                   0
# region                    0
# crop_type                 0
# soil_moisture_%           0
# soil_pH                   0
# temperature_C             0
# rainfall_mm               0
# humidity_%                0
# sunlight_hours            0
# irrigation_type         150
# fertilizer_type           0
# pesticide_usage_ml        0
# sowing_date               0
# harvest_date              0
# total_days                0
# yield_kg_per_hectare      0
# sensor_id                 0
# timestamp                 0
# latitude                  0
# longitude                 0
# NDVI_index                0
# crop_disease_status     130
# product_price             0
# quantity_sold             0
# revenue                   0
# discount_pct              0
# dtype: int64

# %% [markdown]
# #Analysis
# two columns have missing data: irrigation_type, crop_disease_status

# %% [markdown]
# #Data Cleaning

# %%
df.drop(columns= ['sensor_id','Unnamed: 0' ]) #drop unuseful columns
# Out:
#       farm_id       region crop_type  soil_moisture_%  soil_pH  temperature_C  \
# 0    FARM0001  North India     Wheat            35.95     5.99          17.79
# 1    FARM0002    South USA   Soybean            19.74     7.24          30.18
# 2    FARM0003    South USA     Wheat            29.32     7.16          27.37
# 3    FARM0004  Central USA     Maize            17.33     6.03          33.73
# 4    FARM0005  Central USA    Cotton            19.37     5.92          33.86
# ..        ...          ...       ...              ...      ...            ...
# 495  FARM0496  Central USA      Rice            42.85     6.70          30.85
# 496  FARM0497  North India   Soybean            34.22     6.75          17.46
# 497  FARM0498  North India    Cotton            15.93     5.72          17.03
# 498  FARM0499  Central USA   Soybean            38.61     6.20          17.08
# 499  FARM0500  North India     Wheat            30.22     7.42          20.57
#
#      rainfall_mm  humidity_%  sunlight_hours irrigation_type  ...  \
# 0          75.62       77.03            7.27             NaN  ...
# 1          89.91       61.13            5.67       Sprinkler  ...
# 2         265.43       68.87            8.23            Drip  ...
# 3         212.01       70.46            5.03       Sprinkler  ...
# 4         269.09       55.73            7.93             NaN  ...
# ..           ...         ...             ...             ...  ...
# 495        52.35       79.58            7.25          Manual  ...
# 496       256.23       45.14            5.78             NaN  ...
# 497       288.96       57.87            7.69            Drip  ...
# 498       279.06       73.09            9.60            Drip  ...
# 499        72.61       89.74            5.09             NaN  ...
#
#     yield_kg_per_hectare  timestamp   latitude  longitude  NDVI_index  \
# 0                4408.07  3/19/2024  14.970941  82.997689        0.63
# 1                5389.98  4/21/2024  16.613022  70.869009        0.58
# 2                2931.16  2/28/2024  19.503156  79.068206        0.80
# 3                4227.80  5/14/2024  31.071298  85.519998        0.44
# 4                4979.96  4/13/2024  16.568540  81.691720        0.84
# ..                   ...        ...        ...        ...         ...
# 495              4251.40   5/8/2024  30.386623  76.147700        0.59
# 496              3708.54  1/19/2024  18.832748  75.736924        0.85
# 497              2604.41  4/20/2024  23.262016  81.992230        0.71
# 498              2586.36   3/2/2024  19.764989  84.426869        0.77
# 499              5891.40  5/11/2024  13.455532  88.880605        0.85
#
#      crop_disease_status product_price  quantity_sold       revenue  \
# 0                   Mild    441.931674           4581  2.024489e+06
# 1                    NaN    392.567828           6707  2.632952e+06
# 2                   Mild    395.141076           3786  1.496004e+06
# 3                    NaN    498.480245           3719  1.853848e+06
# 4                 Severe    421.311871           6424  2.706507e+06
# ..                   ...           ...            ...           ...
# 495                 Mild    431.705242           3749  1.618463e+06
# 496               Severe    412.649580           3141  1.296132e+06
# 497                 Mild    411.125407           2510  1.031925e+06
# 498               Severe    475.739509           2608  1.240729e+06
# 499               Severe    458.518936           5233  2.399430e+06
#
#      discount_pct
# 0        0.149062
# 1        0.042628
# 2        0.048842
# 3        0.061032
# 4        0.036854
# ..            ...
# 495      0.093179
# 496      0.138337
# 497      0.008706
# 498      0.033543
# 499      0.123968
#
# [500 rows x 25 columns]

# %%
df["product_price"] = np.random.normal(420, 40, len(df))

df["quantity_sold"] = (
    df["yield_kg_per_hectare"] * np.random.uniform(0.8, 1.3, len(df))
).astype(int)

df["revenue"] = df["product_price"] * df["quantity_sold"]

df["discount_pct"] = np.random.uniform(0, 0.15, len(df)) #percentage discount during sales

# %%
df.head(5)
# Out:
#     farm_id       region crop_type  soil_moisture_%  soil_pH  temperature_C  \
# 0  FARM0001  North India     Wheat            35.95     5.99          17.79
# 1  FARM0002    South USA   Soybean            19.74     7.24          30.18
# 2  FARM0003    South USA     Wheat            29.32     7.16          27.37
# 3  FARM0004  Central USA     Maize            17.33     6.03          33.73
# 4  FARM0005  Central USA    Cotton            19.37     5.92          33.86
#
#    rainfall_mm  humidity_%  sunlight_hours irrigation_type  ... sensor_id  \
# 0        75.62       77.03            7.27             NaN  ...  SENS0001
# 1        89.91       61.13            5.67       Sprinkler  ...  SENS0002
# 2       265.43       68.87            8.23            Drip  ...  SENS0003
# 3       212.01       70.46            5.03       Sprinkler  ...  SENS0004
# 4       269.09       55.73            7.93             NaN  ...  SENS0005
#
#    timestamp   latitude  longitude  NDVI_index  crop_disease_status  \
# 0  3/19/2024  14.970941  82.997689        0.63                 Mild
# 1  4/21/2024  16.613022  70.869009        0.58                  NaN
# 2  2/28/2024  19.503156  79.068206        0.80                 Mild
# 3  5/14/2024  31.071298  85.519998        0.44                  NaN
# 4  4/13/2024  16.568540  81.691720        0.84               Severe
#
#   product_price quantity_sold       revenue  discount_pct
# 0    441.931674          4581  2.024489e+06      0.149062
# 1    392.567828          6707  2.632952e+06      0.042628
# 2    395.141076          3786  1.496004e+06      0.048842
# 3    498.480245          3719  1.853848e+06      0.061032
# 4    421.311871          6424  2.706507e+06      0.036854
#
# [5 rows x 26 columns]

# %%
import numpy as np
import pandas as pd

# -----------------------------
# RANDOM SEED FOR REPRODUCIBILITY
# -----------------------------
np.random.seed(42)

# Assume your dataframe already exists
# df = pd.read_csv("your_dataset.csv")

# -----------------------------
# MARKET & ECONOMIC FEATURES
# -----------------------------

# Corn futures price ($/bushel)
df["corn_futures_price"] = np.random.normal(6.2, 0.7, len(df)).round(2)

# Soybean futures price ($/bushel)
df["soybean_futures_price"] = np.random.normal(13.5, 1.2, len(df)).round(2)

# Fertilizer market index
df["fertilizer_market_index"] = np.random.normal(110, 15, len(df)).round(2)

# Diesel price ($/gallon)
df["diesel_price"] = np.random.normal(4.1, 0.4, len(df)).round(2)

# Inflation rate (%)
df["inflation_rate"] = np.random.uniform(2.0, 8.0, len(df)).round(2)

# Competitor product price
df["competitor_price"] = (
    df["product_price"] * np.random.uniform(0.9, 1.1, len(df))
).round(2)

# -----------------------------
# CUSTOMER & DEMAND FEATURES
# -----------------------------

# Customer segment
customer_segments = ["Small Farm", "Commercial", "Enterprise", "Cooperative"]

df["customer_segment"] = np.random.choice(
    customer_segments,
    len(df)
)

# Farm size (hectares)
df["farm_size_hectares"] = np.random.randint(10, 5000, len(df))

# Purchase frequency per year
df["purchase_frequency"] = np.random.randint(1, 15, len(df))

# Customer lifetime value ($)
df["customer_lifetime_value"] = np.random.normal(
    25000,
    8000,
    len(df)
).round(2)

# Demand index
df["demand_index"] = np.random.uniform(0.5, 1.5, len(df)).round(2)

# Regional market share (%)
df["regional_market_share_pct"] = np.random.uniform(
    1,
    35,
    len(df)
).round(2) #the estimated percentage of the regional market controlled by a farm, supplier, or agribusiness entity.
##| Value | Meaning                    |
##| ----- | -------------------------- |
##| 2%    | very small market presence |
##| 10%   | moderate market share      |
##| 25%   | dominant regional supplier |
##| 35%   | major market leader        |##


# -----------------------------
# TEMPORAL FEATURES
# -----------------------------

# Convert dates to datetime
df["sowing_date"] = pd.to_datetime(df["sowing_date"])
df["harvest_date"] = pd.to_datetime(df["harvest_date"])
df['timestamp'] = pd.to_datetime(df['timestamp'])
# Extract week
df["week"] = df["timestamp"].dt.isocalendar().week

# Extract quarter
df["quarter"] = df["timestamp"].dt.quarter

# Season mapping
def get_season(month):
    if month in [12, 1, 2]:
        return "Winter"
    elif month in [3, 4, 5]:
        return "Spring"
    elif month in [6, 7, 8]:
        return "Summer"
    else:
        return "Fall"

df["season"] = df["timestamp"].dt.month.apply(get_season)

# Holiday flag
df["holiday_flag"] = np.random.choice(
    [0, 1],
    len(df),
    p=[0.9, 0.1]
)

# -----------------------------
# ENVIRONMENTAL RISK FEATURES
# -----------------------------

# Drought index
df["drought_index"] = np.random.uniform(0, 5, len(df)).round(2)

# Heat stress index
df["heat_stress_index"] = (
    (df["temperature_C"] / 40) * 100
).round(2)

# Flood risk score
df["flood_risk_score"] = np.random.uniform(
    0,
    100,
    len(df)
).round(2)

# Soil health score
df["soil_health_score"] = np.random.uniform(
    50,
    100,
    len(df)
).round(2)

# Crop disease risk
disease_risk = ["Low", "Moderate", "High"]

df["crop_disease_risk"] = np.random.choice(
    disease_risk,
    len(df),
    p=[0.6, 0.3, 0.1]
)

# Water availability index
df["water_availability_index"] = np.random.uniform(
    0,
    1,
    len(df)
).round(2)

# -----------------------------
# INVENTORY & SUPPLY CHAIN
# -----------------------------

# Inventory level
df["inventory_level"] = np.random.randint(
    100,
    5000,
    len(df)
)

# Supplier risk score
df["supplier_risk_score"] = np.random.uniform(
    0,
    100,
    len(df)
).round(2)

##..delayed shipments
#geopolitical exposure
#higher procurement costs
##| Score  | Meaning                     |
##| ------ | --------------------------- |
##| 0–20   | Very low supplier risk      |
#| 20–50  | Moderate supplier risk      |
#| 50–80  | Elevated supplier risk      |
#| 80–100 | Severe supplier instability |

# Logistics cost ($)
df["logistics_cost"] = np.random.normal(
    500,
    120,
    len(df)
).round(2)

# Lead time (days): the number of days required for goods, supplies, or inventory to arrive after an order is placed.
df["lead_time_days"] = np.random.randint(
    1,
    30,
    len(df))
#reduce sales
#create stockouts
#hurt customer retention

# -----------------------------
# PROFITABILITY FEATURES
# -----------------------------

# Unit production cost
df["unit_cost"] = (df["product_price"] * np.random.uniform(0.5, 0.85, len(df))
).round(2)

# Profit margin: #the percentage of profit earned after subtracting production or operational costs from the selling price.
df["profit_margin"] = ((df["product_price"] - df["unit_cost"]) / df["product_price"]
    * 100).round(2) #i.e percentage of production cost

# -----------------------------
# AI PRICING RECOMMENDATION
# -----------------------------

def pricing_recommendation(row):

    if row["drought_index"] > 3 and row["demand_index"] > 1.1:
        return "Increase price by 5%"

    elif row["inventory_level"] > 4000:
        return "Offer 10% discount"

    elif row["competitor_price"] < row["product_price"]:
        return "Reduce price by 3%"

    else:
        return "Maintain current pricing"

df["pricing_recommendation"] = df.apply(
    pricing_recommendation,
    axis=1
)

# -----------------------------
# AI BUSINESS EXPLANATION
# -----------------------------

def recommendation_reason(row):

    if row["drought_index"] > 3:
        return "High drought risk increasing regional demand pressure."

    elif row["inventory_level"] > 4000:
        return "Excess inventory detected."

    elif row["competitor_price"] < row["product_price"]:
        return "Competitor pricing pressure identified."

    else:
        return "Market conditions stable."

df["pricing_recommendation_reason"] = df.apply(
    recommendation_reason,
    axis=1
)

# -----------------------------
# PREVIEW DATASET
# -----------------------------

print(df.head())

# -----------------------------
# SAVE ENHANCED DATASET
# -----------------------------

df.to_csv(
    "enhanced_agribusiness_pricing_dataset.csv",
    index=False
)

print("Enhanced dataset saved successfully.")
# Out:
#    Unnamed: 0   farm_id       region crop_type  soil_moisture_%  soil_pH  \
# 0           0  FARM0001  North India     Wheat            35.95     5.99
# 1           1  FARM0002    South USA   Soybean            19.74     7.24
# 2           2  FARM0003    South USA     Wheat            29.32     7.16
# 3           3  FARM0004  Central USA     Maize            17.33     6.03
# 4           4  FARM0005  Central USA    Cotton            19.37     5.92
#
#    temperature_C  rainfall_mm  humidity_%  sunlight_hours  ...  \
# 0          17.79        75.62       77.03            7.27  ...
# 1          30.18        89.91       61.13            5.67  ...
# 2          27.37       265.43       68.87            8.23  ...
# 3          33.73       212.01       70.46            5.03  ...
# 4          33.86       269.09       55.73            7.93  ...
#
#   crop_disease_risk water_availability_index  inventory_level  \
# 0               Low                     0.14              476
# 1               Low                     0.78             1072
# 2          Moderate                     0.80             4313
# 3               Low                     0.54             3176
# 4               Low                     0.31              543
#
#   supplier_risk_score logistics_cost  lead_time_days  unit_cost profit_margin  \
# 0               69.82         504.81               7     304.49         17.69
# 1               62.38         248.98              28     365.76         21.82
# 2               18.90         455.70               5     233.47         41.95
# 3               46.94         471.16              15     247.81         41.04
# 4               72.03         410.12              20     202.29         48.88
#
#   pricing_recommendation                      pricing_recommendation_reason
# 0     Reduce price by 3%            Competitor pricing pressure identified.
# 1     Reduce price by 3%  High drought risk increasing regional demand p...
# 2     Offer 10% discount                         Excess inventory detected.
# 3     Reduce price by 3%            Competitor pricing pressure identified.
# 4     Reduce price by 3%            Competitor pricing pressure identified.
#
# [5 rows x 57 columns]
# Enhanced dataset saved successfully.

# %%
import numpy as np
import pandas as pd

# -----------------------------
# RANDOM SEED FOR REPRODUCIBILITY
# -----------------------------
np.random.seed(42)

# Assume your dataframe already exists
# df = pd.read_csv("your_dataset.csv")

# -----------------------------
# MARKET & ECONOMIC FEATURES
# -----------------------------

# Corn futures price ($/bushel)
df["corn_futures_price"] = np.random.normal(6.2, 0.7, len(df)).round(2)

# Soybean futures price ($/bushel)
df["soybean_futures_price"] = np.random.normal(13.5, 1.2, len(df)).round(2)

# Fertilizer market index
df["fertilizer_market_index"] = np.random.normal(110, 15, len(df)).round(2)

# Diesel price ($/gallon)
df["diesel_price"] = np.random.normal(4.1, 0.4, len(df)).round(2)

# Inflation rate (%)
df["inflation_rate"] = np.random.uniform(2.0, 8.0, len(df)).round(2)

# Competitor product price
df["competitor_price"] = (
    df["product_price"] * np.random.uniform(0.9, 1.1, len(df))
).round(2)

# -----------------------------
# CUSTOMER & DEMAND FEATURES
# -----------------------------

# Customer segment
customer_segments = ["Small Farm", "Commercial", "Enterprise", "Cooperative"]

df["customer_segment"] = np.random.choice(
    customer_segments,
    len(df)
)

# Farm size (hectares)
df["farm_size_hectares"] = np.random.randint(10, 5000, len(df))

# Purchase frequency per year
df["purchase_frequency"] = np.random.randint(1, 15, len(df))

# Customer lifetime value ($)
df["customer_lifetime_value"] = np.random.normal(
    25000,
    8000,
    len(df)
).round(2)

# Demand index
df["demand_index"] = np.random.uniform(0.5, 1.5, len(df)).round(2)

# Regional market share (%)
df["regional_market_share_pct"] = np.random.uniform(
    1,
    35,
    len(df)
).round(2)

# -----------------------------
# TEMPORAL FEATURES
# -----------------------------

# Convert dates to datetime
df["sowing_date"] = pd.to_datetime(df["sowing_date"])
df["harvest_date"] = pd.to_datetime(df["harvest_date"])

# Extract week
df["week"] = df["timestamp"].dt.isocalendar().week

# Extract quarter
df["quarter"] = df["timestamp"].dt.quarter

# Season mapping
def get_season(month):
    if month in [12, 1, 2]:
        return "Winter"
    elif month in [3, 4, 5]:
        return "Spring"
    elif month in [6, 7, 8]:
        return "Summer"
    else:
        return "Fall"

df["season"] = df["timestamp"].dt.month.apply(get_season)

# Holiday flag
df["holiday_flag"] = np.random.choice(
    [0, 1],
    len(df),
    p=[0.9, 0.1]
)

# -----------------------------
# ENVIRONMENTAL RISK FEATURES
# -----------------------------

# Drought index
df["drought_index"] = np.random.uniform(0, 5, len(df)).round(2)

# Heat stress index
df["heat_stress_index"] = (
    (df["temperature_C"] / 40) * 100
).round(2)

# Flood risk score
df["flood_risk_score"] = np.random.uniform(
    0,
    100,
    len(df)
).round(2)

# Soil health score
df["soil_health_score"] = np.random.uniform(
    50,
    100,
    len(df)
).round(2)

# Crop disease risk
disease_risk = ["Low", "Moderate", "High"]

df["crop_disease_risk"] = np.random.choice(
    disease_risk,
    len(df),
    p=[0.6, 0.3, 0.1]
)

# Water availability index
df["water_availability_index"] = np.random.uniform(
    0,
    1,
    len(df)
).round(2)

# -----------------------------
# INVENTORY & SUPPLY CHAIN
# -----------------------------

# Inventory level
df["inventory_level"] = np.random.randint(
    100,
    5000,
    len(df)
)

# Supplier risk score
df["supplier_risk_score"] = np.random.uniform(
    0,
    100,
    len(df)
).round(2)

# Logistics cost ($)
df["logistics_cost"] = np.random.normal(
    500,
    120,
    len(df)
).round(2)

# Lead time (days)
df["lead_time_days"] = np.random.randint(
    1,
    30,
    len(df)
)

# -----------------------------
# PROFITABILITY FEATURES
# -----------------------------

# Unit production cost
df["unit_cost"] = (
    df["product_price"] * np.random.uniform(0.5, 0.85, len(df))
).round(2)

# Profit margin
df["profit_margin"] = (
    (df["product_price"] - df["unit_cost"])
    / df["product_price"]
    * 100
).round(2)

# -----------------------------
# AI PRICING RECOMMENDATION
# -----------------------------

def pricing_recommendation(row):

    if row["drought_index"] > 3 and row["demand_index"] > 1.1:
        return "Increase price by 5%"

    elif row["inventory_level"] > 4000:
        return "Offer 10% discount"

    elif row["competitor_price"] < row["product_price"]:
        return "Reduce price by 3%"

    else:
        return "Maintain current pricing"

df["pricing_recommendation"] = df.apply(
    pricing_recommendation,
    axis=1
)

# -----------------------------
# AI BUSINESS EXPLANATION
# -----------------------------

def recommendation_reason(row):

    if row["drought_index"] > 3:
        return "High drought risk increasing regional demand pressure."

    elif row["inventory_level"] > 4000:
        return "Excess inventory detected."

    elif row["competitor_price"] < row["product_price"]:
        return "Competitor pricing pressure identified."

    else:
        return "Market conditions stable."

df["pricing_recommendation_reason"] = df.apply(
    recommendation_reason,
    axis=1
)

# -----------------------------
# PREVIEW DATASET
# -----------------------------

print(df.head())

# -----------------------------
# SAVE ENHANCED DATASET
# -----------------------------

df.to_csv(
    "enhanced_agribusiness_pricing_dataset.csv",
    index=False
)

print("Enhanced dataset saved successfully.")
# Out:
#    Unnamed: 0   farm_id       region crop_type  soil_moisture_%  soil_pH  \
# 0           0  FARM0001  North India     Wheat            35.95     5.99
# 1           1  FARM0002    South USA   Soybean            19.74     7.24
# 2           2  FARM0003    South USA     Wheat            29.32     7.16
# 3           3  FARM0004  Central USA     Maize            17.33     6.03
# 4           4  FARM0005  Central USA    Cotton            19.37     5.92
#
#    temperature_C  rainfall_mm  humidity_%  sunlight_hours  ...  \
# 0          17.79        75.62       77.03            7.27  ...
# 1          30.18        89.91       61.13            5.67  ...
# 2          27.37       265.43       68.87            8.23  ...
# 3          33.73       212.01       70.46            5.03  ...
# 4          33.86       269.09       55.73            7.93  ...
#
#   crop_disease_risk water_availability_index  inventory_level  \
# 0               Low                     0.14              476
# 1               Low                     0.78             1072
# 2          Moderate                     0.80             4313
# 3               Low                     0.54             3176
# 4               Low                     0.31              543
#
#   supplier_risk_score logistics_cost  lead_time_days  unit_cost profit_margin  \
# 0               69.82         504.81               7     304.49         17.69
# 1               62.38         248.98              28     365.76         21.82
# 2               18.90         455.70               5     233.47         41.95
# 3               46.94         471.16              15     247.81         41.04
# 4               72.03         410.12              20     202.29         48.88
#
#   pricing_recommendation                      pricing_recommendation_reason
# 0     Reduce price by 3%            Competitor pricing pressure identified.
# 1     Reduce price by 3%  High drought risk increasing regional demand p...
# 2     Offer 10% discount                         Excess inventory detected.
# 3     Reduce price by 3%            Competitor pricing pressure identified.
# 4     Reduce price by 3%            Competitor pricing pressure identified.
#
# [5 rows x 57 columns]
# Enhanced dataset saved successfully.

# %%
df.head(5)
# Out:
#    Unnamed: 0   farm_id       region crop_type  soil_moisture_%  soil_pH  \
# 0           0  FARM0001  North India     Wheat            35.95     5.99
# 1           1  FARM0002    South USA   Soybean            19.74     7.24
# 2           2  FARM0003    South USA     Wheat            29.32     7.16
# 3           3  FARM0004  Central USA     Maize            17.33     6.03
# 4           4  FARM0005  Central USA    Cotton            19.37     5.92
#
#    temperature_C  rainfall_mm  humidity_%  sunlight_hours  ...  \
# 0          17.79        75.62       77.03            7.27  ...
# 1          30.18        89.91       61.13            5.67  ...
# 2          27.37       265.43       68.87            8.23  ...
# 3          33.73       212.01       70.46            5.03  ...
# 4          33.86       269.09       55.73            7.93  ...
#
#   crop_disease_risk water_availability_index  inventory_level  \
# 0               Low                     0.14              476
# 1               Low                     0.78             1072
# 2          Moderate                     0.80             4313
# 3               Low                     0.54             3176
# 4               Low                     0.31              543
#
#   supplier_risk_score logistics_cost  lead_time_days  unit_cost profit_margin  \
# 0               69.82         504.81               7     304.49         17.69
# 1               62.38         248.98              28     365.76         21.82
# 2               18.90         455.70               5     233.47         41.95
# 3               46.94         471.16              15     247.81         41.04
# 4               72.03         410.12              20     202.29         48.88
#
#   pricing_recommendation                      pricing_recommendation_reason
# 0     Reduce price by 3%            Competitor pricing pressure identified.
# 1     Reduce price by 3%  High drought risk increasing regional demand p...
# 2     Offer 10% discount                         Excess inventory detected.
# 3     Reduce price by 3%            Competitor pricing pressure identified.
# 4     Reduce price by 3%            Competitor pricing pressure identified.
#
# [5 rows x 57 columns]

# %%
df.crop_type.unique()
# Out:
# array(['Wheat', 'Soybean', 'Maize', 'Cotton', 'Rice'], dtype=object)

# %%
df.region.unique()
# Out:
# array(['North India', 'South USA', 'Central USA', 'East Africa',
#        'South India'], dtype=object)

# %%
hormuz_scenarios = [
    "normal",
    "moderate_disruption",
    "severe_disruption",
    "closure"
]

df["hormuz_scenario"] = np.random.choice(
    hormuz_scenarios,
    len(df),
    p=[0.65, 0.20, 0.10, 0.05]
)

# %%
df.head(3)
# Out:
#    Unnamed: 0   farm_id       region crop_type  soil_moisture_%  soil_pH  \
# 0           0  FARM0001  North India     Wheat            35.95     5.99
# 1           1  FARM0002    South USA   Soybean            19.74     7.24
# 2           2  FARM0003    South USA     Wheat            29.32     7.16
#
#    temperature_C  rainfall_mm  humidity_%  sunlight_hours  ...  \
# 0          17.79        75.62       77.03            7.27  ...
# 1          30.18        89.91       61.13            5.67  ...
# 2          27.37       265.43       68.87            8.23  ...
#
#   water_availability_index inventory_level  supplier_risk_score  \
# 0                     0.14             476                69.82
# 1                     0.78            1072                62.38
# 2                     0.80            4313                18.90
#
#   logistics_cost lead_time_days  unit_cost  profit_margin  \
# 0         504.81              7     304.49          17.69
# 1         248.98             28     365.76          21.82
# 2         455.70              5     233.47          41.95
#
#   pricing_recommendation                      pricing_recommendation_reason  \
# 0     Reduce price by 3%            Competitor pricing pressure identified.
# 1     Reduce price by 3%  High drought risk increasing regional demand p...
# 2     Offer 10% discount                         Excess inventory detected.
#
#      hormuz_scenario
# 0             normal
# 1  severe_disruption
# 2             normal
#
# [3 rows x 58 columns]

# %%
def oil_shock_multiplier(scenario):

    if scenario == "normal":
        return np.random.uniform(0.98, 1.03)

    elif scenario == "moderate_disruption":
        return np.random.uniform(1.08, 1.18)

    elif scenario == "severe_disruption":
        return np.random.uniform(1.20, 1.40)

    else:
        return np.random.uniform(1.45, 1.80)

df["oil_price_shock_multiplier"] = df[
    "hormuz_scenario"
].apply(oil_shock_multiplier)

# %%
df["adjusted_diesel_price"] = (
    df["diesel_price"]
    * df["oil_price_shock_multiplier"]
).round(2)

# %%
df["adjusted_fertilizer_index"] = (
    df["fertilizer_market_index"] * ( 1 + ((df["oil_price_shock_multiplier"] - 1)
            * 0.75 ))).round(2)

# %%
df["adjusted_logistics_cost"] = ( df["logistics_cost"] * ( 1 + ((df["oil_price_shock_multiplier"] - 1)
            * 0.60))).round(2)

# %%
df["farm_input_inflation_pct"] = (
    ((df["adjusted_fertilizer_index"] - df["fertilizer_market_index"])/ df["fertilizer_market_index"]
    )* 100).round(2)

# %%
df["revenue_at_risk"] = (
    df["revenue"] * (df["farm_input_inflation_pct"] / 100 )
).round(2)

# %%
# ---------------------------------------------------------
# Adjusted unit production cost after geopolitical shock
# ---------------------------------------------------------

df["adjusted_unit_cost"] = (
    df["unit_cost"]
    * (1 + (df["farm_input_inflation_pct"] / 100)* 0.55)).round(2)

# %%
df["margin_compression_pct"] = (
    (
        (df["adjusted_unit_cost"] - df["unit_cost"] )/ df["unit_cost"] )
    * 100
).round(2)#the percentage increase in operational costs caused by inflation, geopolitical disruption, or supply-chain pressure.
#how much profitability is being squeezed
#costs are rising faster than revenue.

#This reduces:

#profitability
#operating margin
#business sustainability

# %%
def geopolitical_strategy(row):

    if row["hormuz_scenario"] == "closure":
        return "Increase prices aggressively"

    elif row["farm_input_inflation_pct"] > 15:
        return "Adjust pricing to protect margins"

    elif row["inventory_level"] > 4000:
        return "Offer targeted discounts"

    else:
        return "Maintain current pricing"

df["geopolitical_pricing_strategy"] = df.apply(
    geopolitical_strategy,
    axis=1
)

# %%
def geopolitical_summary(row):

    if row["hormuz_scenario"] == "closure":

        return (
            "Severe geopolitical disruption detected. "
            "Fuel and fertilizer costs are rising sharply."
        )

    elif row["farm_input_inflation_pct"] > 10:

        return (
            "Input cost inflation increasing operational risk."
        )

    else:

        return (
            "Market conditions remain stable."
        )

df["geopolitical_summary"] = df.apply(
    geopolitical_summary,
    axis=1
)

# %%
df
# Out:
#      Unnamed: 0   farm_id       region crop_type  soil_moisture_%  soil_pH  \
# 0             0  FARM0001  North India     Wheat            35.95     5.99
# 1             1  FARM0002    South USA   Soybean            19.74     7.24
# 2             2  FARM0003    South USA     Wheat            29.32     7.16
# 3             3  FARM0004  Central USA     Maize            17.33     6.03
# 4             4  FARM0005  Central USA    Cotton            19.37     5.92
# ..          ...       ...          ...       ...              ...      ...
# 495         495  FARM0496  Central USA      Rice            42.85     6.70
# 496         496  FARM0497  North India   Soybean            34.22     6.75
# 497         497  FARM0498  North India    Cotton            15.93     5.72
# 498         498  FARM0499  Central USA   Soybean            38.61     6.20
# 499         499  FARM0500  North India     Wheat            30.22     7.42
#
#      temperature_C  rainfall_mm  humidity_%  sunlight_hours  ...  \
# 0            17.79        75.62       77.03            7.27  ...
# 1            30.18        89.91       61.13            5.67  ...
# 2            27.37       265.43       68.87            8.23  ...
# 3            33.73       212.01       70.46            5.03  ...
# 4            33.86       269.09       55.73            7.93  ...
# ..             ...          ...         ...             ...  ...
# 495          30.85        52.35       79.58            7.25  ...
# 496          17.46       256.23       45.14            5.78  ...
# 497          17.03       288.96       57.87            7.69  ...
# 498          17.08       279.06       73.09            9.60  ...
# 499          20.57        72.61       89.74            5.09  ...
#
#          hormuz_scenario oil_price_shock_multiplier  adjusted_diesel_price  \
# 0                 normal                   1.007821                   4.44
# 1      severe_disruption                   1.303522                   5.06
# 2                 normal                   1.022939                   3.86
# 3                 normal                   1.012590                   4.15
# 4    moderate_disruption                   1.098876                   4.43
# ..                   ...                        ...                    ...
# 495    severe_disruption                   1.342322                   6.08
# 496  moderate_disruption                   1.171811                   4.79
# 497               normal                   0.992426                   3.72
# 498               normal                   1.010662                   4.07
# 499               normal                   1.000020                   3.80
#
#     adjusted_fertilizer_index adjusted_logistics_cost  \
# 0                      131.76                  507.18
# 1                      152.07                  294.32
# 2                      112.80                  461.97
# 3                      101.25                  474.72
# 4                      129.40                  434.45
# ..                        ...                     ...
# 495                    176.06                  742.81
# 496                    159.08                  610.22
# 497                    127.40                  519.48
# 498                    126.36                  542.96
# 499                    118.89                  537.51
#
#      farm_input_inflation_pct  adjusted_unit_cost margin_compression_pct  \
# 0                        0.59              305.48                   0.33
# 1                       22.77              411.57                  12.52
# 2                        1.72              235.68                   0.95
# 3                        0.95              249.10                   0.52
# 4                        7.41              210.53                   4.07
# ..                        ...                 ...                    ...
# 495                     25.68              250.58                  14.12
# 496                     12.89              318.18                   7.09
# 497                     -0.57              342.90                  -0.31
# 498                      0.80              212.25                   0.44
# 499                      0.00              279.08                   0.00
#
#          geopolitical_pricing_strategy  \
# 0             Maintain current pricing
# 1    Adjust pricing to protect margins
# 2             Offer targeted discounts
# 3             Maintain current pricing
# 4             Maintain current pricing
# ..                                 ...
# 495  Adjust pricing to protect margins
# 496           Maintain current pricing
# 497           Maintain current pricing
# 498           Offer targeted discounts
# 499           Offer targeted discounts
#
#                                   geopolitical_summary
# 0                     Market conditions remain stable.
# 1    Input cost inflation increasing operational risk.
# 2                     Market conditions remain stable.
# 3                     Market conditions remain stable.
# 4                     Market conditions remain stable.
# ..                                                 ...
# 495  Input cost inflation increasing operational risk.
# 496  Input cost inflation increasing operational risk.
# 497                   Market conditions remain stable.
# 498                   Market conditions remain stable.
# 499                   Market conditions remain stable.
#
# [500 rows x 67 columns]

# %%
#df.to_csv('/content/AI_Smart_Agribusiness_Final.csv')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #Clean the data

# %%
df = pd.read_csv("/content/sample_data/AI_Smart_Agribusiness_Final2.csv")

# %%
df.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'farm_id', 'region', 'crop_type',
#        'soil_moisture_%', 'soil_pH', 'temperature_C', 'rainfall_mm',
#        'humidity_%', 'sunlight_hours', 'irrigation_type', 'fertilizer_type',
#        'pesticide_usage_ml', 'sowing_date', 'harvest_date', 'total_days',
#        'yield_kg_per_hectare', 'sensor_id', 'timestamp', 'latitude',
#        'longitude', 'NDVI_index', 'crop_disease_status', 'product_price',
#        'quantity_sold', 'revenue', 'discount_pct', 'corn_futures_price',
#        'soybean_futures_price', 'fertilizer_market_index', 'diesel_price',
#        'inflation_rate', 'competitor_price', 'customer_segment',
#        'farm_size_hectares', 'purchase_frequency', 'customer_lifetime_value',
#        'demand_index', 'regional_market_share_pct', 'week', 'quarter',
#        'season', 'holiday_flag', 'drought_index', 'heat_stress_index',
#        'flood_risk_score', 'soil_health_score', 'crop_disease_risk',
#        'water_availability_index', 'inventory_level', 'supplier_risk_score',
#        'logistics_cost', 'lead_time_days', 'unit_cost', 'profit_margin',
#        'pricing_recommendation', 'pricing_recommendation_reason',
#        'hormuz_scenario', 'oil_price_shock_multiplier',
#        'adjusted_diesel_price', 'adjusted_fertilizer_index',
#        'adjusted_logistics_cost', 'farm_input_inflation_pct',
#        'adjusted_unit_cost', 'margin_compression_pct',
#        'geopolitical_pricing_strategy', 'geopolitical_summary'],
#       dtype='object')

# %%
df.head(3)
# Out:
#    Unnamed: 0.1  Unnamed: 0   farm_id       region crop_type  soil_moisture_%  \
# 0             0           0  FARM0001  North India     Wheat            35.95
# 1             1           1  FARM0002    South USA   Soybean            19.74
# 2             2           2  FARM0003    South USA     Wheat            29.32
#
#    soil_pH  temperature_C  rainfall_mm  humidity_%  ...    hormuz_scenario  \
# 0     5.99          17.79        75.62       77.03  ...             normal
# 1     7.24          30.18        89.91       61.13  ...  severe_disruption
# 2     7.16          27.37       265.43       68.87  ...             normal
#
#   oil_price_shock_multiplier adjusted_diesel_price  adjusted_fertilizer_index  \
# 0                   1.007821                  4.44                     131.76
# 1                   1.303522                  5.06                     152.07
# 2                   1.022939                  3.86                     112.80
#
#   adjusted_logistics_cost farm_input_inflation_pct  adjusted_unit_cost  \
# 0                  507.18                     0.59              305.48
# 1                  294.32                    22.77              411.57
# 2                  461.97                     1.72              235.68
#
#    margin_compression_pct      geopolitical_pricing_strategy  \
# 0                    0.33           Maintain current pricing
# 1                   12.52  Adjust pricing to protect margins
# 2                    0.95           Offer targeted discounts
#
#                                 geopolitical_summary
# 0                   Market conditions remain stable.
# 1  Input cost inflation increasing operational risk.
# 2                   Market conditions remain stable.
#
# [3 rows x 68 columns]

# %%
df.head(3)
# Out:
#     farm_id       region crop_type  soil_moisture_%  soil_pH  temperature_C  \
# 0  FARM0001  North India     Wheat            35.95     5.99          17.79
# 1  FARM0002    South USA   Soybean            19.74     7.24          30.18
# 2  FARM0003    South USA     Wheat            29.32     7.16          27.37
#
#    rainfall_mm  humidity_%  sunlight_hours irrigation_type  ...  \
# 0        75.62       77.03            7.27             NaN  ...
# 1        89.91       61.13            5.67       Sprinkler  ...
# 2       265.43       68.87            8.23            Drip  ...
#
#      hormuz_scenario  oil_price_shock_multiplier adjusted_diesel_price  \
# 0             normal                    1.007821                  4.44
# 1  severe_disruption                    1.303522                  5.06
# 2             normal                    1.022939                  3.86
#
#   adjusted_fertilizer_index  adjusted_logistics_cost  \
# 0                    131.76                   507.18
# 1                    152.07                   294.32
# 2                    112.80                   461.97
#
#    farm_input_inflation_pct adjusted_unit_cost  margin_compression_pct  \
# 0                      0.59             305.48                    0.33
# 1                     22.77             411.57                   12.52
# 2                      1.72             235.68                    0.95
#
#        geopolitical_pricing_strategy  \
# 0           Maintain current pricing
# 1  Adjust pricing to protect margins
# 2           Offer targeted discounts
#
#                                 geopolitical_summary
# 0                   Market conditions remain stable.
# 1  Input cost inflation increasing operational risk.
# 2                   Market conditions remain stable.
#
# [3 rows x 65 columns]

# %%
df.rev

# %%
df.columns
# Out:
# Index(['farm_id', 'region', 'crop_type', 'soil_moisture_%', 'soil_pH',
#        'temperature_C', 'rainfall_mm', 'humidity_%', 'sunlight_hours',
#        'irrigation_type', 'fertilizer_type', 'pesticide_usage_ml',
#        'sowing_date', 'harvest_date', 'total_days', 'yield_kg_per_hectare',
#        'timestamp', 'latitude', 'longitude', 'NDVI_index',
#        'crop_disease_status', 'product_price', 'quantity_sold', 'revenue',
#        'discount_pct', 'corn_futures_price', 'soybean_futures_price',
#        'fertilizer_market_index', 'diesel_price', 'inflation_rate',
#        'competitor_price', 'customer_segment', 'farm_size_hectares',
#        'purchase_frequency', 'customer_lifetime_value', 'demand_index',
#        'regional_market_share_pct', 'week', 'quarter', 'season',
#        'holiday_flag', 'drought_index', 'heat_stress_index',
#        'flood_risk_score', 'soil_health_score', 'crop_disease_risk',
#        'water_availability_index', 'inventory_level', 'supplier_risk_score',
#        'logistics_cost', 'lead_time_days', 'unit_cost', 'profit_margin',
#        'pricing_recommendation', 'pricing_recommendation_reason',
#        'hormuz_scenario', 'oil_price_shock_multiplier',
#        'adjusted_diesel_price', 'adjusted_fertilizer_index',
#        'adjusted_logistics_cost', 'farm_input_inflation_pct',
#        'adjusted_unit_cost', 'margin_compression_pct',
#        'geopolitical_pricing_strategy', 'geopolitical_summary'],
#       dtype='object')

# %%
df.drop(columns=['Unnamed: 0.1', 'Unnamed: 0', 'sensor_id'], inplace= True) #drop unnessary columns

# %%
from sklearn.impute import SimpleImputer

num_col = df.select_dtypes(include = 'number').columns
cat_col = df.select_dtypes(include = ['object','category']).columns

#fill missing numerical columns with the mean
num_imputer = SimpleImputer(strategy='mean')
df[num_col] = num_imputer.fit_transform(df[num_col])

#fill missing categorical with mode
col_imputer = SimpleImputer(strategy = 'most_frequent')
df[cat_col] = col_imputer.fit_transform(df[cat_col])

print(df.isnull().sum())
# Out:
# farm_id                          0
# region                           0
# crop_type                        0
# soil_moisture_%                  0
# soil_pH                          0
#                                 ..
# farm_input_inflation_pct         0
# adjusted_unit_cost               0
# margin_compression_pct           0
# geopolitical_pricing_strategy    0
# geopolitical_summary             0
# Length: 65, dtype: int64

# %%
df.to_csv('AI_Smart_Agribusiness_Final_3.csv')

# %% [markdown]
# #DESCRIBTIVE STATISTICS

# %%
total_revenue = df["revenue"].sum()

avg_profit_margin = df["profit_margin"].mean()

avg_revenue_risk = df["revenue_at_risk"].mean()

avg_demand = df["demand_index"].mean()

print("Total Revenue:", total_revenue)
print("Average Profit Margin:", avg_profit_margin)
print("Average Revenue Risk:", avg_revenue_risk)
print("Average Demand Index:", avg_demand)
# Out:
# Total Revenue: 890228676.0884343
# Average Profit Margin: 32.83398
# Average Revenue Risk: 128507.05478
# Average Demand Index: 0.9836199999999999

# %% [markdown]
# *Total Revenue: 890,228,676.09
# This is the sum of all revenue generated across the dataset.
# It means the business generated approximately $890.23 million in sales.
#
# *Average Profit Margin: 32.83%
# Profit margin measures how much profit is retained from revenue after costs.
# An average margin of 32.83% means: For every $1 of revenue, the business keeps about $0.33 as profit.
#
# *Average Revenue Risk: 128,507.05
# This likely represents the average financial exposure or uncertainty in revenue.
# Depending on how you calculated it, it may reflect:
# *   volatility,
# *   potential losses,
# *   forecast uncertainty,
# *   supply chain disruptions,
# *   climate/oil-price shocks,
# *   or demand instability.
#
# Interpretation:
# On average, about $128.5k of revenue is exposed to risk or variability per observation/unit/region/time period.
# If this came from simulation or shock modeling, it indicates how sensitive revenue is to disruptions.
#
# *Average Demand Index: 0.9836
# A demand index is usually a normalized indicator where:
#
# *   1.0 = baseline/expected demand
# *   greater 1.0 = above-normal demand
# *   <1.0 = below-normal demand

# %% [markdown]
# #summary of the statistics above:
# Together, these metrics tell a useful business story:
#
# Revenue is very high (~$890M)
# Profitability is healthy (~33% margin)
# There is moderate revenue uncertainty/risk
# Demand remains close to stable baseline levels
#
# This combination suggests:
#
# the business is profitable,
# but external shocks or operational volatility may still threaten revenue stability.

# %% [markdown]
# #estimate revenue by crop tpe

# %%
crop_revenue = df.groupby('crop_type')['revenue'].sum().reset_index()

fig = px.bar(crop_revenue,
             x='crop_type',
             y = 'revenue',
             title = 'Revenue by crop type',
             text_auto= True)
# Make ALL chart text bold
fig.update_layout(
    title={
        'x': 0.5,
        'xanchor': 'center',
        'font': dict(
            family='Arial Black',
            size=22
        )
    },

    font=dict(
        family='Arial Black',
        size=14
    ),

    xaxis=dict(
        title='<b>Crop Type</b>',
        tickfont=dict(size=13)
    ),

    yaxis=dict(
        title='<b>Revenue</b>',
        tickfont=dict(size=13)))

# Make bar labels bold
fig.update_traces(
    #texttemplate='<b>%{text}</b>',
    textposition='outside',
    textfont=dict(
        family='Arial Black',
        size=12))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1992c3af-aec3-4a96-8ceb-6e5d2bd49a65" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1992c3af-aec3-4a96-8ceb-6e5d2bd49a65")) {                    Plotly.newPlot(                        "1992c3af-aec3-4a96-8ceb-6e5d2bd49a65",                        [{"alignmentgroup":"True","hovertemplate":"crop_type=%{x}\u003cbr\u003erevenue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"outside","texttemplate":"%{y}","x":["Cotton","Maize","Rice","Soybean","Wheat"],"xaxis":"x","y":[187521401.71784934,188045189.38295326,142015299.48118582,202808541.51003107,169838243.9964148],"yaxis":"y","type":"bar","textfont":{"family":"Arial Black","size":12}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width" ...

# %% [markdown]
# the chart shows that soybean followed by maize and cotton have the highest revenue
